# %% [markdown]
# # Fuel Mix
#
# Grabs Fuel Mix from gridiso.com

# %%
#import modules 
from gridstatusio import GridStatusClient

#run authtication key for grid status .com

# %%
#run authentication key for grid status .com 
client = GridStatusClient(api_key = '28f0ccadc0c6467484338079b260f22f')

#Set query limits 

QUERY_LIMIT = 10000

# %%
#list datasets

client.list_datasets(filter_term='CAISO')
# Out:
# +-------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |           Key           |                                                                                     Value                                                                                      |
# +-------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |          Name           |                                                                                CAISO AS Prices                                                                                 |
# ...
